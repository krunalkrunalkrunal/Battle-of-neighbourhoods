# %% [markdown]
# # The Battle of the Neighborhoods - Week 1_2

# %% [markdown]
# ## Data:

# %% [markdown]
# City of interest in this project: Toronto

# %% [markdown]
# We will be using the below datasets for analysing Toronto city

# %% [markdown]
# ## Data 1

# %% [markdown]
# Data from this location
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# This is a list of postal codes in Canada where the first letter is M. Postal codes beginning with M are located within the city of Toronto in the province of Ontario. Only the first three characters are listed, corresponding to the Forward Sortation Area.
#
# This dataset provide the list of Borough and neighbourhood associated with the postal codes of the city of Toronto

# %% [markdown]
# We will use this data to categorize Boroughs and neighbourhood base on postal codes and then will merge with the foursquare data

# %% [markdown]
# Below is an example of the data from wikipedia link mentioned above:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://github.com/krunalkrunalkrunal/Battle-of-neighbourhoods/blob/master/image1.jpg

# %% [markdown]
# ## Data 2

# %% [markdown]
# Toronto city geographical coordinates data will be utilized as input for the Foursquare API, that will be leveraged to provision venues information for each neighborhood.

# %% [markdown]
# We will use the Foursquare API to explore neighborhoods in Toronto city. We will use this data to figure out which neighbourhood has as many as amenities and facilities that fits with the clients requirement

# %% [markdown]
# We will cluster this data using neighboughhood to figure out which area best fits with the client requirements to figure out location to buy a new house

# %% [markdown]
# Below is an example of the data from foursquare:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://github.com/krunalkrunalkrunal/Battle-of-neighbourhoods/blob/master/image2.jpg

# %% [markdown]
# **Note**: Detailed Dataframes will be visible in the notebook for the week 2 assignment with detailed an|alysis
